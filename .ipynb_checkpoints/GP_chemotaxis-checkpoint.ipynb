# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import time
import math
from scipy.stats import vonmises  #for von Mises distribution
import scipy.optimize   #for log-likelihood

% matplotlib inline

# %% [markdown]
# ## SDE for Chemotaxis
#
# Two chemotactic strategies are used in parallel, as shown in the SDE that governs the head direction below. The "weathervane" method compares concentration perpendicular to the moving direction in the last step (can consider a temporal window in the future too) and gradually/continuously moves twoards the side with higher concentration. The "run-and-tumble" method is a classic biased random walk known in bacteria, where the direction of motion changes drastically (with a certain probability) when the concentration is decreasing. Here is the form in 2-D random walk:
#
# ### $\frac{d\theta_t}{dt} = \alpha(\theta^*-\theta) + \beta_t \eta + \epsilon_t$
#
# $\theta^*$ is the direction of target (similar to O-U process) and $\beta_t =
#   \begin{cases}
#     1       & p\\
#     0       & 1-p
#   \end{cases}$
#
# The both the target orientation $\theta^*$ and probability $p$ to turning drastically are a function of concentration experienced in the environment and would be specified in the discrete settings.
#
# ### $v = N(v_m,\Sigma_v)$
#
# ### $\frac{dx}{dt} = v\cos(\theta_t)$
#
# ### $\frac{dx}{dt} = v\sin(\theta_t)$

# %% [markdown]
# ## Discrete time fitting
#
# ### $d\theta_t = N(\alpha * \delta C_{t \bot}, K) + \beta_t U(0,2\pi)$
#
# ### $\beta_t =
#   \begin{cases}
#     1       & p\\
#     0       & 1-p
#   \end{cases}
# $
# ### $p = \frac{1}{1+e^{-w^T\delta C_t}}$
#
# ### $\delta C = C_{t} - C_{t-1}$  $\text( parallel)$
#
# ### $\delta C = C_{t \bot} - C_{t-1 \bot}$  $\text( perpendicular)$
#
# ### $Parameters = \{\alpha, K, w\}$
#
# - Wheatervaning strength $\alpha$, random-walk noise $K$, and tumble activation function $w$
#
# ### $Data = \{ d\theta_t, \delta C_t, \delta C_{t \bot} \}$

# %% [markdown]
# ### Idea:
#
# $d\theta_t = \alpha \delta C_{t\bot} + \eta_K$
#
# $\eta = N(0,K)$
#
# Regression on $d\theta$-$\delta C_{t\bot}$ to find $\alpha$ and $K$
#
# Cluster $d\theta$ and fit for the logistic activation function separately
#
# ### Questions:
# - stationary vs. non-stationary covariance for GP regression?
#
# As the mean $\alpha\delta C_{t\bot}$ changes through time (depending on the concentration in environment it experiences), this is different from the O-U process (where the Gaussian process simply has a exponential kernel with fixed length scale). Maybe a way to connect to non-stationary GP is needed? https://users.aalto.fi/~ssarkka/course_ox2013/pdf/handout6.pdf
#
# - Currently not using the temporal information but only fitting on discret angles and concentrations?
#
# There is temporal correlation in the SDE form, where the parameter $\theta$ would have a correlation time scale of $\frac{1}{\alpha}$ if we ignore the sparse switching part (run-and-tumble). However, it seems that my current method is not using this information but fitting the response function to concentrations separately.

# %% [markdown]
# ### Use log-likelihood analysis
#
# https://www.wikiwand.com/en/Von_Mises_distribution
#
# https://stats.stackexchange.com/questions/325517/maximum-likelihood-estimation-to-fit-von-mises-to-grouped-interval-circular-da
#
# ### Try AR1 to weathervaning part
#
# ...or temporal smooothing kernel
#
# ### $d\theta_t = N(\vec{\alpha} * \delta C_{t \bot}, K) + \beta_t(\vec{w}) U(0,2\pi)$
#
# ### $\beta_t =
#   \begin{cases}
#     1       & p\\
#     0       & 1-p
#   \end{cases}
# $
# ### $p = \frac{1}{1+e^{-\vec{w}^T\delta C_t}}$

# %% [markdown]
# ## Log-likelihood approach
#
# ### $log(\prod P(\theta_t)) = \Sigma log((1-p)VM(d\theta _t | \alpha * \delta C_{t \bot}, K) + p U(0,2\pi))$
#
# ### $logP(\{d\theta_t\} | data, \Theta) = \Sigma log ((1-P)(\frac{e^{Kcos(d\theta_t - \alpha \delta C_{t\bot})}}{2\pi I_0(K)}) + P\frac{1}{2\pi})$

# %%
#hybrid Gaussian process for angle time series
def d_theta(alpha, dc_perp, K, w, dC):
    '''
    Return change in theta angle for each step
    Input with alpha for weighting, dc for orthogonal concentration difference, and K covariance in weathervaning
    W as the weighting/kernel on concentration in the signoidal function for tumbling rate 
    '''
    wv = alpha*dc_perp + K*np.random.randn()  #weathervaning strategy
    #P_event = 0.023/(0.4 + np.exp(140*dC/dt)) + 0.003  #sigmoidal function with parameters w
    P_event = 5*0.023/(1 + np.exp(140*(dC/dt) + 0))  #less parameter version
    if np.random.rand() < P_event:
        beta = 1
    else:
        beta = 0
    rt = beta*(np.random.rand()*360 - 180) #(2*np.pi)  #run-and-tumble strategy
    #rt = beta*(np.random.randn()*K + 100)  #alternative Gaussian mixture
    dth = wv + rt
    if dth > 180:
        dth = dth-360  #bounded by angle measurements
    if dth < -180:
        dth = dth+360
    return dth

# %%
#gradient environment
dis2targ = 50
C0 = 0.2
D = 0.000015
duT = 60*60*3
d = 0.18
def gradient(C0,x,y):
    concentration = C0/(4*np.pi*d*D*duT)*np.exp(-(x-dis2targ)**2/(400*D*duT*50))  #depends on diffusion conditions
    return concentration

# %%
#measure for concentration difference for weathervane
def dc_measure(dxy,xx,yy):
    perp_dir = np.array([-dxy[1], dxy[0]])
    perp_dir = perp_dir/np.linalg.norm(perp_dir)
    perp_dC = gradient(C0, xx+perp_dir[0], yy+perp_dir[1]) - gradient(C0, xx-perp_dir[0], yy-perp_dir[1])
    return perp_dC

# %%
alpha = 25  #strength of OU forcing
K = 5  #covariance of weathervane
w = 0  #logistic parameter (default for now)
T = 5000
dt = 0.6  #seconds
v_m = 0.12  #mm/s
v_s = 0.01  #std of speed
time = np.arange(0,T*dt,dt)
xs = np.zeros(time.shape)
ys = np.zeros(time.shape)  #2D location
xs[0] = np.random.randn()
ys[0] = np.random.randn()
ths = np.zeros(time.shape)  #agle with 1,0
ths[0] = np.random.randn()
dxy = np.random.randn(2)

#with turning (Brownian-like tragectories)
for t in range(1,len(time)):
    
    #concentration = gradient(C0,xs[t-1],ys[t-1])
    dC = gradient(C0, xs[t-1],ys[t-1]) - gradient(C0, xs[t-2],ys[t-2])
    dc_perp = dc_measure(dxy,xs[t-1],ys[t-1])      
    dth = d_theta(alpha, -dc_perp, K, 0, dC)
    ths[t] = ths[t-1] + dth*dt
    
    e1 = np.array([1,0])
    vec = np.array([xs[t-1],ys[t-1]])
    theta = math.acos(np.clip(np.dot(vec,e1)/np.linalg.norm(vec)/np.linalg.norm(e1), -1, 1)) #current orienation relative to (1,0)

    vv = v_m + v_s*np.random.randn()
    dd = np.array([vv*np.sin(ths[t]*np.pi/180), vv*np.cos(ths[t]*np.pi/180)])  #displacement
    c, s = np.cos(theta), np.sin(theta)
    R = np.array(((c,s), (-s, c)))  #rotation matrix, changing coordinates
    dxy = np.dot(R,dd)
    
    xs[t] = xs[t-1] + dxy[0]*dt
    ys[t] = ys[t-1] + dxy[1]*dt

    
#plt.plot(ths)
plt.figure()
plt.plot(xs,ys)

# %%
plt.plot(autocorr(dcps[:1000]))

# %%
x = np.arange(np.min(xs),np.max(xs),1)
xx_grad = C0/(4*np.pi*d*D*duT)*np.exp(-(x-dis2targ)**2/(400*D*duT*50))
plt.imshow(np.expand_dims(xx_grad,axis=1).T,extent=[np.min(xs),np.max(xs),np.min(ys),np.max(ys)])
plt.hold(True)
plt.plot(xs,ys,'white')

# %%
all_dc_p = []
all_dc = []
all_th = []
for ii in range(20):
    xs = np.zeros(time.shape)
    ys = np.zeros(time.shape)  #2D location
    xs[0] = np.random.randn()*0.1
    ys[0] = np.random.randn()*0.1
    ths = np.zeros(time.shape)  #agle with 1,0
    ths[0] = np.random.rand()*0
    dcs = np.zeros(time.shape)
    dcps = np.zeros(time.shape)
    dths = np.zeros(time.shape)
    for t in range(1,len(time)):
        
        dC = gradient(C0, xs[t-1],ys[t-1]) - gradient(C0, xs[t-2],ys[t-2])
        dc_perp = dc_measure(dxy,xs[t-1],ys[t-1])      
        dth = d_theta(alpha, -dc_perp, K, 0, dC)
        ths[t] = ths[t-1] + dth*dt
        
        dcs[t] = dC
        dcps[t] = dc_perp
        dths[t] = dth
        
        
        e1 = np.array([1,0])
        vec = np.array([xs[t-1],ys[t-1]])
        theta = math.acos(np.clip(np.dot(vec,e1)/np.linalg.norm(vec)/np.linalg.norm(e1), -1, 1)) #current orienation relative to (1,0)

        vv = v_m + v_s*np.random.randn()
        dd = np.array([vv*np.sin(ths[t]*np.pi/180), vv*np.cos(ths[t]*np.pi/180)])  #displacement
        c, s = np.cos(theta), np.sin(theta)
        R = np.array(((c,s), (-s, c)))  #rotation matrix, changing coordinates
        dxy = np.dot(R,dd)

        xs[t] = xs[t-1] + dxy[0]*dt
        ys[t] = ys[t-1] + dxy[1]*dt
        
    all_dc_p.append(dcps)  #recording dC_perpendicular
    all_dc.append(dcs)  #recording dC
    all_th.append(dths)  #recording head angle
        
    plt.plot(xs,ys)
    plt.hold(True)

# %% [markdown]
# ## Miture model for two "states"

# %%
#data array prep
data_th = np.array(all_th).reshape(-1)
data_dcp = np.array(all_dc_p).reshape(-1)
data_dc = np.array(all_dc).reshape(-1)

# %% [markdown]
# ### von Mises fitting
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.vonmises.html

# %%
d2r = np.pi/180
vm_par = vonmises.fit((data_th-alpha*data_dcp)*d2r, scale=1)

# %%
plt.hist((data_th-alpha*data_dcp)*d2r,bins=100,normed=True);
plt.hold(True)
xx = np.linspace(np.min(data_th*d2r),np.max(data_th*d2r),100)
rv = vonmises(vm_par[0])
plt.plot(xx, rv.pdf(xx),linewidth=3)
plt.xlabel('dtheta-a*dCp')

# %%
plt.hist(alpha*data_dcp*d2r,bins=100,normed=True);
plt.xlabel('a*dCp')

# %%
#negative log-likelihood
def nLL(THETA, dth,dcp,dc):
    """
    negative log-likelihood
    """
    a_,k_,A_,B_,C_ = THETA  #inferred paramter (biase alpha, noise K, and sigmoid A and B)
    #a_,k_,A_,B_,C_,D_ = THETA
    P = sigmoid2(A_,B_,C_,dc)
    #P = sigmoid1(A_,B_,C_,D_,dc)
    #VM = np.exp(k_*np.cos((dth-a_*dcp)*d2r)) / (2*np.pi*iv(0,k_))#von Mises distribution
    #vm_par = vonmises.fit((dth-a_*dcp)*d2r, scale=1)
    #rv = vonmises(k_)#(vm_par[0])
    VM = vonmises.pdf((dth-a_*dcp)*d2r,k_,loc=0, scale=1)  #input, kappa, loc=0, and scale=1
    marginalP = np.multiply((1-P), VM) + (1/(2*np.pi))*P
    nll = -np.sum(np.log(marginalP+1e-7))#, axis=1)
    #fst = np.einsum('ij,ij->i', 1-P, VM)
    #snd = np.sum(1/np.pi*P, axis=1)
    return np.sum(nll)

def sigmoid2(a,b,c,x):
    """
    simplified sigmoid with less parameter
    """
    y = a / (1 + np.exp(b*x + c))
    ###Simulated function
    #P_event = 0.023/(1 + np.exp(140*dC/dt + c))
    return y

def sigmoid1(a,b,c,d,x):
    """
    sigmoid with all parameter accoridng to the literature
    """
    y = a / (b + np.exp(c*x)) +d
    ###Simulated function
    #P_event = 0.023/(0.4 + np.exp(40*dC/dt)) + 0.003
    return y

# %%
#check density
THETA = theta_guess
a_,k_,A_,B_,C_ = THETA  #inferred paramter (biase alpha, noise K, and sigmoid A and B)
P = sigmoid2(A_,B_,C_,data_dc)
VM = vonmises.pdf((data_th-a_*data_dcp)*d2r, k_, loc=0, scale=1)  #input, kappa, loc=0, and scale=1
marginalP = np.multiply((1-P), VM) + (1/(2*np.pi))*P
nll = -np.sum(np.log(marginalP+1e-7))#, axis=1)
np.sum(nll)
# Out:
# 113634.18060947601

# %%
###test robustness of optimization with Hessian
from numdifftools import Jacobian, Hessian

# def fun_der(x, dth,dcp,dc):
#     return Jacobian(lambda x: nLL(x, dth,dcp,dc))(x).ravel()

# def fun_hess(x, dth,dcp,dc):
#     return Hessian(lambda x: nLL(x, dth,dcp,dc))(x)


# res = scipy.optimize.minimize(nLL, theta_guess, args=(data_th,data_dcp,data_dc) \
#                               , method='BFGS', jac=fun_der, hess=fun_hess)

# %%
#optimization
theta_guess = 1,1,0.1,100,3  #a_, k_, A_, B_, C_
#theta_guess = 1,1,0.1,1,10,0.001  #a_, k_, A_, B_, C_, D_ 
###Ground Truth: 25,5,0.023,0.4,40,0.003
res = scipy.optimize.minimize(nLL,np.array(theta_guess),args=(data_th[:],data_dcp[:],data_dc[:]),method='Nelder-Mead')
#,bounds = ((0,None),(0,None),(None,None),(None,None)))
theta_fit = res.x
# Out:
# /Users/Macintosh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:15: RuntimeWarning: invalid value encountered in log

# %%
res
#Ground Truth: 25, 5, 0.023, 20
###alpha is currect as there's a negative sign for dC_perb in the iteration!
###Kappa in the von Mises is compared below
###left with the sigmoidal fit~~~ (successful with two parameters but not with intersection)
# Out:
#  final_simplex: (array([[  -21.1482149 ,   116.80019645,    -6.50661291, -2798.81782566,
#            82.56240309],
#        [  -21.14821444,   116.80019646,    -6.50661287, -2798.81777699,
#            82.56239984],
#        [  -21.14821424,   116.80019647,    -6.50661285, -2798.81775605,
#            82.56239842],
#        [  -21.14821453,   116.80019649,    -6.50661288, -2798.81778624,
#            82.56240042],
#        [  -21.14821459,   116.80019652,    -6.50661289, -2798.81779341,
#            82.56240088],
#        [  -21.1482145 ,   116.80019649,    -6.50661288, -2798.81778339,
#            82.56240023]]), array([-16508.29194534, -16508.29194534, -16508.29194534, -16508.29194534,
#        -16508.29194534, -16508.29194534]))
#            fun: -16508.291945337787
#        message: 'Optimization terminated successfully.'
#           nfev: 521
#            nit: 285
#         status: 0
#        success: True
# ...

# %%
#plt.hist((data_th-alpha*data_dcp)*d2r,bins=100,normed=True,color='r');
aa,bb = np.histogram((data_th-alpha*data_dcp)*d2r,bins=200)
plt.bar(bb[:-1],aa/len(data_th),align='edge',width=0.03)
plt.hold(True)
rv = vonmises(res.x[1])
#plt.scatter((data_th-alpha*data_dcp)*d2r,rv.pdf((data_th-alpha*data_dcp)*d2r),s=1,marker='.')
plt.bar(bb[:-1],rv.pdf(bb[:-1])*np.mean(np.diff(bb)),alpha=0.5,align='center',width=0.03,color='r')
plt.axis([-1,1,0,0.2])

#normalization by bin size???
#checking pdf density
print('sum of histogram:',np.sum(aa/len(data_th)))
print('integrate von Mises:',np.sum(rv.pdf(bb[:-1])*np.mean(np.diff(bb))))
# Out:
# sum of histogram: 1.0
# integrate von Mises: 1.0

# %%
xp = np.linspace(-0.1, 0.1, 1500)
pxp=sigmoid2(res.x[2],res.x[3],res.x[4],xp)
#pxp=sigmoid1(res.x[2],res.x[3],res.x[4],res.x[5],xp)

plt.plot(xp,pxp,'-',linewidth=3,label='fit')
plt.hold(True)
plt.plot(xp,sigmoid2(5*0.023, 140/0.6, 3,xp),linewidth=5,label='ground-truth',alpha=0.5)
#plt.plot(xp,sigmoid1(0.023,0.4,140/0.6,0.003,xp),linewidth=3,label='ground-truth')
plt.xlabel('x')
plt.ylabel('y',rotation='horizontal') 
plt.grid(True)
plt.legend()

# %%
###concentration change is correlated!
#-> find temproal kernel or decorrelation methods
def autocorr(x):
    """
    Autocorrelation function for time-series
    """
    result = np.correlate(x, x, mode='full')
    return result[result.size // 2:]
plt.plot(autocorr(data_dc[:5000]))
plt.xlabel('time shift')
plt.ylabel('auto-correlation')

# %%
aa,bb = np.histogram(np.abs(data_th),bins=50)
plt.semilogy(bb[:-1],aa)
plt.xlabel('abs(dth)')
plt.ylabel('count')

# %%
###state building temporal kernel for sensing
def temporal_kernel(alpha,tau):
    """
    biphasic temporal kernel
    tau is the temporal domain and alpha controls the form
    """
    D_tau = alpha*np.exp(-alpha*tau)*((alpha*tau)**5/math.factorial(5) - (alpha*tau)**7/math.factorial(7))
    return D_tau

tt = np.linspace(0,10,10/0.6)
plt.plot(tt,-temporal_kernel(2.,tt),'-o')
# Out:
# /Users/Macintosh/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
tr = 10
plt.subplot(1,2,1)
plt.title('dc')
plt.plot(np.array(all_dc)[tr,:])
plt.xlabel('time')
plt.subplot(1,2,2)
plt.title('angle')
plt.plot(np.array(all_th)[tr,:])
plt.xlabel('time')

# %%
#dc vs. dtheta
plt.plot(data_dcp.T, data_th.T, 'o');
plt.ylabel('d_theta')
plt.xlabel('d_c')

# %%
#distribution of angles
plt.hist(data_th.reshape(-1), bins=100);
plt.xlabel('d_theta')
plt.ylabel('count')

# %%
### Miture model test ###
# test = 0
# test = np.random.randn(1000)
# test = np.concatenate(((np.random.rand(1000)-np.mean(test))*3, test))
# plt.hist(test,bins=100);

# gmm = mixture.GaussianMixture(n_components=2, covariance_type='full')  #can put more components here (ex: speed and angle)
# gmm.fit(np.expand_dims(test,axis=1))

# mix = gmm.predict(np.expand_dims(test,axis=1))#, gmm.means_, gmm.covariances_)

# g1 = np.where(mix==0)[0]
# plt.plot(test,'bo')
# plt.hold(True)
# plt.plot(test[g1],'ro')

# %%
#fitting miture model for all dtheta distribution
from sklearn import mixture
gmm = mixture.GaussianMixture(n_components=2, covariance_type='full')  #can put more components here (ex: speed and angle)
gmm.fit(np.expand_dims(data_th.reshape(-1),axis=1))
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
mix = gmm.predict(np.expand_dims(data_th.reshape(-1),axis=1))#, gmm.means_, gmm.covariances_)

# %%
#mark in time series
wv = np.where(mix==0)[0]
rt = np.where(mix!=0)[0]
plt.plot(wv,data_th.reshape(-1)[wv],'bo')
plt.hold(True)
plt.plot(rt,data_th.reshape(-1)[rt],'ro')
plt.ylabel('d_theta')
plt.xlabel('time')

# %% [markdown]
# ## GP fitting
#
# - for weathervaning strategy

# %%
#GP regression for weathervane

#data_wv = data_th[data_th<30]  #.copy()
#data_dc_wv = data_dcp[data_th<30]

data_wv = data_th.reshape(-1)[wv]
data_dc_wv = data_dcp.reshape(-1)[wv]

plt.plot(data_dc_wv.T, data_wv.T, 'o',alpha=0.1);
plt.xlabel('d_theta')
plt.ylabel('d_angle')

# %%
#sub-sampling first
#data_dc_wv = data_dc_wv[data_dc_wv.argsort()]
#data_dc_ = data_dc_wv[data_dc_wv.argsort()]

dsamp = 2000
from scipy import signal
sub_dc = signal.resample(data_dc_wv, dsamp);
sub_dth = signal.resample(data_wv, dsamp);

#sub_dc = data_dc_wv.copy()
#sub_dth = data_wv.copy()
# Out:
# /Users/Macintosh/anaconda/lib/python3.5/site-packages/scipy/signal/signaltools.py:2223: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[sl] = X[sl]
# /Users/Macintosh/anaconda/lib/python3.5/site-packages/scipy/signal/signaltools.py:2225: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[sl] = X[sl]
# ...

# %%
plt.plot(sub_dc, sub_dth, 'o')
plt.xlabel('d_theta')
plt.ylabel('d_angle')

# %%
from sklearn import gaussian_process
from sklearn.gaussian_process.kernels import Matern, WhiteKernel, ConstantKernel, RBF

# %%
### GP Regression
gp = gaussian_process.GaussianProcessRegressor(kernel = Matern())  #kernel_exp(kernel_RBF, 1))
gp.fit(np.expand_dims(sub_dc, axis=1), sub_dth)  #np.expand_dims(sub_dth, axis=1))
# Out:
# GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=Matern(length_scale=1, nu=1.5), n_restarts_optimizer=0,
#              normalize_y=False, optimizer='fmin_l_bfgs_b',
#              random_state=None)

# %%
xx = np.linspace(-0.1,0.1,100)
y_pred, sigma = gp.predict(np.expand_dims(xx,axis=1), return_std=True)

plt.figure()
plt.plot(sub_dc, sub_dth, 'r.', label='data')
plt.plot(xx, y_pred, 'b-', label='prediction')
plt.fill(np.concatenate([xx, xx[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
#plt.legend(loc='upper left')
plt.xlabel('d_theta')
plt.ylabel('d_angle')

# %% [markdown]
# ## Logistic regression
#
# - for run-and-tumble strategy

# %%
data_th = np.array(all_th)
data_dc = np.array(all_dc)

# %%
#GP regression for weathervane
###note that dc in perpendicular orientation is different from tangential direction
#data_rt = data_th.reshape(-1)[rt]
turns = np.zeros(len(data_th.reshape(-1)))
turns[rt] = 1
data_dc_rt = data_dc.reshape(-1)#[rt]

plt.plot(data_dc_rt[:-1], turns[1:], '.',alpha=0.5)
plt.xlabel('d_c')
plt.ylabel('state')

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(np.expand_dims(data_dc_rt[1:],axis=1), turns[:-1])
xx = np.linspace(-0.1,0.1,1000)
def model(x):
    return 1 / (1 + np.exp(-x))
loss = model(xx * clf.coef_ + clf.intercept_).ravel()
plt.plot(xx, loss, color='red', linewidth=3)
#plt.hold(True)
#plt.plot(data_dc_rt, turns.T, '.',alpha=0.5);

# %%
###Simulation for sigmoid regression
xs = np.random.randn(10000)*0.05
P_event = 0.023/(0.4 + np.exp(40*xs)) + 0.003
randtemp = np.random.rand(len(P_event))
compare = P_event>randtemp
binout = np.zeros(len(compare))
binout[compare==True] = 1
plt.plot(xs,binout,'*')

# %%
### Use optimization function
import scipy.optimize 
def sigmoid(p,x):
    a,b,c,d = p
    y = a / (b + np.exp(c*x)) + d
    ###Simulated function
    #P_event = 0.023/(0.4 + np.exp(40*dC/dt)) + 0.003
    return y

def residuals(p,x,y):
    return y - sigmoid(p,x)

# raw data
x = data_dc_rt[:-1]
y = turns[1:]
#x = xs
#y = binout

p_guess = 0.01,0.1,10,0.001
#np.random.rand(4)#0.023,0.4,40,0.003 #(np.median(x),np.median(y),1.0,1.0)
p, cov, infodict, mesg, ier = scipy.optimize.leastsq(residuals,p_guess,args=(x,y),full_output=1)
p
# Out:
# array([2.60075720e-02, 5.26785400e-01, 6.36027864e+01, 1.46671975e-03])

# %%
xp = np.linspace(-0.1, 0.1, 1500)
pxp=sigmoid(p,xp)

# Plot the results
plt.plot(x*10, y*0.1,'.')
plt.plot(xp,pxp,'-',linewidth=3,label='fit')
plt.hold(True)
plt.plot(xp,sigmoid((0.023,0.4,40,0.003),xp),linewidth=3,label='ground-truth')
plt.xlabel('x')
plt.ylabel('y',rotation='horizontal') 
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Entropic Environment

# %% [markdown]
# #### Questions:
#
# - spatial scale vs. scales in the chemotaxis strategy (smoothness and time scale)
#
# - optimal parameters of two strategies given an environment (weightings and exploitation)

# %%
# xx = np.exp(np.linspace(-50,50,20)/100)
# yy = np.linspace(-50,50,20)
# XX, YY = np.meshgrid(xx,yy)
# eta = 0.1
# XXen = XX + np.random.randn(XX.shape[0],XX.shape[1])*eta
# YYen = YY + np.random.randn(YY.shape[0],YY.shape[1])*eta
# plt.scatter(XXen,YYen)

# %%
randtemp = np.random.randn(100,100)
from scipy import signal
smoothK = np.ones((3,3))
grad = signal.convolve2d(randtemp, smoothK, boundary='symm', mode='same')
ent_env = grad/np.max(grad)

# %%
plt.subplot(1,2,1)
plt.imshow(ent_env)
plt.subplot(1,2,2)
plt.hist(ent_env.reshape(-1),50);

# %%
ent_env[ent_env<0] = 0
plt.imshow(ent_env)

# %%
def dc_measure2(Camp, dxy,xx,yy):
    perp_dir = np.array([-dxy[1], dxy[0]])
    perp_dir = perp_dir/np.linalg.norm(perp_dir)
    perp_dC = ent_env[round(int(xx+perp_dir[0])), round(int(yy+perp_dir[1]))] - ent_env[round(int(xx-perp_dir[0])), round(int(yy-perp_dir[1]))]
    return Camp*perp_dC

# %%
Camp = 0.2
alpha = 25  #strength of OU forcing
K = 5  #covariance of weathervane
w = 0  #logistic parameter (default for now)
T = 3000
dt = 0.6  #seconds
v_m = 0.12  #mm/s
v_s = 0.01  #std of speed
time = np.arange(0,T*dt,dt)

rep = 10
accum = np.zeros(rep)

for tr in range(rep):
    xs = np.zeros(time.shape)
    ys = np.zeros(time.shape)  #2D location
    xs[0] = 50  #middle of the environment
    ys[0] = 50
    ths = np.zeros(time.shape)  #agle with 1,0
    ths[0] = np.random.randn()
    dxy = np.random.randn(2)

    for t in range(1,len(time)):
        
        accum[tr] = accum[tr] + ent_env[round(int(xs[t-1])),round(int(ys[t-1]))]
        dC = Camp*(ent_env[round(int(xs[t-1])),round(int(ys[t-1]))] - ent_env[round(int(xs[t-2])),round(int(ys[t-2]))])
        dc_perp = dc_measure2(Camp, dxy,xs[t-1],ys[t-1])      
        dth = d_theta(alpha, -dc_perp, K, 0, dC)
        ths[t] = ths[t-1] + dth*dt

        e1 = np.array([1,0])
        vec = np.array([xs[t-1],ys[t-1]])
        theta = math.acos(np.clip(np.dot(vec,e1)/np.linalg.norm(vec)/np.linalg.norm(e1), -1, 1)) #current orienation relative to (1,0)

        vv = v_m + v_s*np.random.randn()
        dd = np.array([vv*np.sin(ths[t]*np.pi/180), vv*np.cos(ths[t]*np.pi/180)])  #displacement
        c, s = np.cos(theta), np.sin(theta)
        R = np.array(((c,s), (-s, c)))  #rotation matrix, changing coordinates
        dxy = np.dot(R,dd)

        xs[t] = xs[t-1] + dxy[0]*dt
        ys[t] = ys[t-1] + dxy[1]*dt

#plt.plot(ths)
#plt.figure()
    plt.plot(xs,ys)
plt.hold(True)
plt.imshow(ent_env, extent=[0,100,0,100])

# %%
accum
# Out:
# array([454.84215882, 233.16266904, 295.69757279, 372.24505349,
#        231.18593984, 591.56933426, 485.66795115, 511.19272745,
#        515.45112777, 437.09932889])

# %%
accum
# Out:
# array([454.84215882, 233.16266904, 295.69757279, 372.24505349,
#        231.18593984, 591.56933426, 485.66795115, 511.19272745,
#        515.45112777, 437.09932889])

# %%
plt.imshow(ent_env, extent=[0,100,0,100])
plt.hold(True)
plt.plot(xs,ys,'white')
